# %%
from pydataset import data
import pandas as pd
from sqlalchemy import create_engine,text
import os

# %%
df=pd.read_csv("C:/analytics/data/students2.csv")

# %%
print(df)
# Out:
#     rollno        name  gender         dob  height program
# 0        1    Jugurtha    Male  2000-08-16     156     BCA
# 1        2    Amandeep  Female  2000-02-21     170     BBA
# 2        3      Barkat  Female  2001-07-17     158     BCA
# 3        4      Suroor  Female  2001-11-16     188     BBA
# 4        5     Sultana    Male  2001-04-02     167     BCA
# 5        6      Sajjad    Male  2000-10-12     153     BCA
# 6        7      Sharan    Male  2000-07-28     174     BBA
# 7        8    Djedjiga  Female  2000-06-27     163     BCA
# 8        9      Bijata  Female  2002-05-14     158     BBA
# 9       10      Mahadi  Female  2000-03-06     175     BCA
# 10      11      Sundas    Male  2000-03-02     151     BCA
# 11      12      Mandal    Male  2000-07-10     169     BBA
# 12      13      Najmul  Female  2001-03-23     177     BCA
# 13      14       Deniz    Male  2001-04-21     156     BBA
# 14      15     Sharmin    Male  2002-10-31     157     BCA
# ...

# %%
df.to_csv('C:/analytics/data/students4.csv')

# %%
engine1=("mysql+pymysql:/piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# mysql+pymysql:/piuser:Pass%40123@localhost:3306/piit

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql (text(sql),conn,params=params)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql (text(sql),conn,params=params)

# %%
q('show tables')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 q('show tables')
#
# Cell In[39], line 2, in q(sql, **params)
#       1 def q(sql,**params):
# ----> 2     with engine1.connect () as conn:
#       3         return pd.read_sql (text(sql),conn,params=params)
#
# AttributeError: 'str' object has no attribute 'connect'

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql (text(sql),conn,params=params)

# %%
q('show tables')
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2              class1
# 3              class2
# 4           crimedata
# 5         departments
# 6   employee_earnings
# 7           employees
# 8      exceldatafile1
# 9              mtcars
# 10           obisdata
# 11            patient
# 12         piitstdata
# 13             record
# 14           students
# 15          students2
# 16              team1

# %%
q('select * from class1 limit 5')
# Out:
#    roll_no first_name last_name  nationality  age  gender  score
# 0        1   AKHANGSH    MANDAL       NEPALI   24    MALE    879
# 1        2     SUROOR    AHMAED     AMERICAN   25  FEMALE    857
# 2        3   MUHAMMAD    KABEER  BANGLADESHI   40    MALE    873
# 3        4    NAYEEMA    ZANNAT  BANGLADESHI   24  FEMALE    832
# 4        5   JUGARTHA  HALCHEMI      TURKISH   30    MALE    798
