# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path = 'C:/analytics/data/students2.csv'
print (file_path)
# Out:
# C:/analytics/data/students2.csv

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#    rollno      name  gender         dob  height program
# 0       1  Jugurtha    Male  2000-08-16     156     BCA
# 1       2  Amandeep  Female  2000-02-21     170     BBA
# 2       3    Barkat  Female  2001-07-17     158     BCA
# 3       4    Suroor  Female  2001-11-16     188     BBA
# 4       5   Sultana    Male  2001-04-02     167     BCA

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path = 'C:/analytics/data/students2.csv'
print (file_path)
# Out:
# C:/analytics/data/students2.csv

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    rollno      name  gender         dob  height program
# 0       1  Jugurtha    Male  2000-08-16     156     BCA
# 1       2  Amandeep  Female  2000-02-21     170     BBA
# 2       3    Barkat  Female  2001-07-17     158     BCA
# 3       4    Suroor  Female  2001-11-16     188     BBA
# 4       5   Sultana    Male  2001-04-02     167     BCA

# %%
import pandas as pd
import numpy as np 
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path = 'C:/analytics/data/exceldatafile2.csv'
print (file_path)
# Out:
# C:/analytics/data/exceldatafile2.csv

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0 StudentID FirstName LastName Gender Class AdmissionDate  \
# 0           0      S001     Aarav   Sharma      M   12A    2024-04-15
# 1           1      S002    Vivaan    Verma      F   12A    2024-04-21
# 2           2      S003    Aditya    Gupta      M   12A    2024-05-19
# 3           3      S004    Vihaan    Mehta      M   12C    2024-06-11
# 4           4      S005     Arjun    Singh      M   12C    2022-06-22
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 0         NaN   ASSIGN 1        NaN        NaN         NaN          NaN
# 1         NaN  StudentID  FirstName   LastName         NaN          NaN
# 2         NaN       S001      Aarav     Sharma         NaN          NaN
# 3         NaN       S002     Vivaan      Verma         NaN          NaN
# 4         NaN      S0007   NOTFOUND   NOTFOUND     IFERROR          NaN
#
#     Unnamed: 12
# 0   Concatinate
# 1  Aarav Sharma
# 2  Vivaan Verma
# 3  Aditya Gupta
# 4  Vihaan Mehta

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path = 'C:/analytics/data/exceldatafile1.csv'
print(file_path)
# Out:
# C:/analytics/data/exceldatafile1.csv

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#   StudentID FirstName LastName Gender Class AdmissionDate  Unnamed: 6  \
# 0      S001     Aarav   Sharma      M   12A     4/15/2024         NaN
# 1      S002    Vivaan    Verma      F   12A     4/21/2024         NaN
# 2      S003    Aditya    Gupta      M   12A     5/19/2024         NaN
# 3      S004    Vihaan    Mehta      M   12C     6/11/2024         NaN
# 4      S005     Arjun    Singh      M   12C     6/22/2022         NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11   Unnamed: 12
# 0   ASSIGN 1        NaN        NaN         NaN          NaN   Concatinate
# 1  StudentID  FirstName   LastName         NaN          NaN  Aarav Sharma
# 2       S001      Aarav     Sharma         NaN          NaN  Vivaan Verma
# 3       S002     Vivaan      Verma         NaN          NaN  Aditya Gupta
# 4      S0007   NOTFOUND   NOTFOUND     IFERROR          NaN  Vihaan Mehta

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import os

# %%
file_path='C:/analytics/data/employees.csv'
df.head()
# Out:
#   StudentID FirstName LastName Gender Class AdmissionDate  Unnamed: 6  \
# 0      S001     Aarav   Sharma      M   12A     4/15/2024         NaN
# 1      S002    Vivaan    Verma      F   12A     4/21/2024         NaN
# 2      S003    Aditya    Gupta      M   12A     5/19/2024         NaN
# 3      S004    Vihaan    Mehta      M   12C     6/11/2024         NaN
# 4      S005     Arjun    Singh      M   12C     6/22/2022         NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  Unnamed: 11   Unnamed: 12
# 0   ASSIGN 1        NaN        NaN         NaN          NaN   Concatinate
# 1  StudentID  FirstName   LastName         NaN          NaN  Aarav Sharma
# 2       S001      Aarav     Sharma         NaN          NaN  Vivaan Verma
# 3       S002     Vivaan      Verma         NaN          NaN  Aditya Gupta
# 4      S0007   NOTFOUND   NOTFOUND     IFERROR          NaN  Vihaan Mehta

# %%
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")

# %%
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
df.to_sql('exceldatafile1', engine1,if_exists= 'append', index=False, chunksize=1000,method='multi')
# Out:
# 40

# %%
df.to_sql('exceldatafile1', engine1, if_exists='append', index=False, chunksize=1000, method='multi')
# Out:
# 40

# %%
df2=pd.read_sql("select * from exceldatafile1,", engine1}
df2.head()
# Out:
#   Cell In[31], line 1
#     df2=pd.read_sql("select * from exceldatafile1,", engine1}
#                                                             ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %%
df2 = pd.read_sql("SELECT * FROM exceldatafile1;", engine1)

# %%
df2.head()
# Out:
#   StudentID FirstName LastName Gender Class AdmissionDate Unnamed: 6  \
# 0      S001     Aarav   Sharma      M   12A    2024-04-15       None
# 1      S002    Vivaan    Verma      F   12A    2024-04-21       None
# 2      S003    Aditya    Gupta      M   12A    2024-05-19       None
# 3      S004    Vihaan    Mehta      M   12C    2024-06-11       None
# 4      S005     Arjun    Singh      M   12C    2022-06-22       None
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11   Unnamed: 12
# 0   ASSIGN 1       None       None        None        None   Concatinate
# 1  StudentID  FirstName   LastName        None        None  Aarav Sharma
# 2       S001      Aarav     Sharma        None        None  Vivaan Verma
# 3       S002     Vivaan      Verma        None        None  Aditya Gupta
# 4      S0007   NOTFOUND   NOTFOUND     IFERROR        None  Vihaan Mehta

# %%
df2.to_csv('C:/analytics/data/exceldatafile2.csv')
