# %%
from pydataset import data
import pandas as pd

# %%
mtcars=data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars[(mtcars['mpg'] > 20) & (mtcars['cyl'] == 4)]
# Out:
#                  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Datsun 710      22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# Merc 240D       24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# Fiat 128        32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# Toyota Corona   21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# Fiat X1-9       27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# Porsche 914-2   26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# Lotus Europa    30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
# Volvo 142E      21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
mtcars[(mtcars['mpg'] > 20) & (mtcars['hp'] < 100) & (mtcars['cyl'] == 4)]
# Out:
#                  mpg  cyl   disp  hp  drat     wt   qsec  vs  am  gear  carb
# Datsun 710      22.8    4  108.0  93  3.85  2.320  18.61   1   1     4     1
# Merc 240D       24.4    4  146.7  62  3.69  3.190  20.00   1   0     4     2
# Merc 230        22.8    4  140.8  95  3.92  3.150  22.90   1   0     4     2
# Fiat 128        32.4    4   78.7  66  4.08  2.200  19.47   1   1     4     1
# Honda Civic     30.4    4   75.7  52  4.93  1.615  18.52   1   1     4     2
# Toyota Corolla  33.9    4   71.1  65  4.22  1.835  19.90   1   1     4     1
# Toyota Corona   21.5    4  120.1  97  3.70  2.465  20.01   1   0     3     1
# Fiat X1-9       27.3    4   79.0  66  4.08  1.935  18.90   1   1     4     1
# Porsche 914-2   26.0    4  120.3  91  4.43  2.140  16.70   0   1     5     2

# %%
mtcars = mtcars.astype({'mpg': int, 'cyl': float})

# %%
mtcars.head()
# Out:
#                    mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4           21  6.0  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag       21  6.0  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710          22  4.0  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive      21  6.0  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout   18  8.0  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars['mpg'] = mtcars['mpg'].astype(int)

# %%
mtcars.head()
# Out:
#                    mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4           21  6.0  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag       21  6.0  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710          22  4.0  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive      21  6.0  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout   18  8.0  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars['mpg'] = mtcars['mpg'] * 2

# %%
mtcars.head()
# Out:
#                    mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4           42  6.0  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag       42  6.0  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710          44  4.0  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive      42  6.0  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout   36  8.0  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars.mpg
# Out:
# Mazda RX4              42
# Mazda RX4 Wag          42
# Datsun 710             44
# Hornet 4 Drive         42
# Hornet Sportabout      36
# Valiant                36
# Duster 360             28
# Merc 240D              48
# Merc 230               44
# Merc 280               38
# Merc 280C              34
# Merc 450SE             32
# Merc 450SL             34
# Merc 450SLC            30
# Cadillac Fleetwood     20
# Lincoln Continental    20
# Chrysler Imperial      28
# Fiat 128               64
# Honda Civic            60
# Toyota Corolla         66
# Toyota Corona          42
# Dodge Challenger       30
# AMC Javelin            30
# Camaro Z28             26
# Pontiac Firebird       38
# Fiat X1-9              54
# Porsche 914-2          52
# Lotus Europa           60
# Ford Pantera L         30
# Ferrari Dino           38
# Maserati Bora          30
# Volvo 142E             42
# Name: mpg, dtype: int64

# %%
mtcars[mtcars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [mpg, cyl, disp, hp, drat, wt, qsec, vs, am, gear, carb]
# Index: []

# %%
##How do you remove whitespace from strings in a DataFrame column?

# %%
mtcars['mpg'] = mtcars['mpg'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 mtcars['mpg'] = mtcars['mpg'].str.strip()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
iris=data('iris')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
iris['Species'] = iris['Species'].str.strip()

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
from pydataset import data

data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
AirPassengers = data ('AirPassengers')
AirPassengers.head()
# Out:
#           time  AirPassengers
# 1  1949.000000            112
# 2  1949.083333            118
# 3  1949.166667            132
# 4  1949.250000            129
# 5  1949.333333            121

# %%
cake=data('cake')
cake.head()
# Out:
#    replicate recipe  temperature  angle  temp
# 1          1      A          175     42   175
# 2          1      A          185     46   185
# 3          1      A          195     47   195
# 4          1      A          205     39   205
# 5          1      A          215     53   215

# %%
#✅ 1. Create a new column by arithmetic

# %%
cake['temperature'] = cake.apply(lambda row: row['temp'] * 0.9, axis=1)

# %%
cake.head()
# Out:
#    replicate recipe  temperature  angle  temp
# 1          1      A        157.5     42   175
# 2          1      A        166.5     46   185
# 3          1      A        175.5     47   195
# 4          1      A        184.5     39   205
# 5          1      A        193.5     53   215

# %%
##✅ Export a DataFrame to Excel

# %%
#df.to_excel("output.xlsx")

# %%
##✅ Basic Statistics for Numeric Columns

# %%
mtcars.describe()
# Out:
#             mpg        cyl        disp          hp       drat         wt  \
# count  32.00000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   39.37500   6.187500  230.721875  146.687500   3.596563   3.217250
# std    11.99395   1.785922  123.938694   68.562868   0.534679   0.978457
# min    20.00000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    30.00000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    38.00000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    44.00000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    66.00000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
##What’s the difference between NumPy arrays and pandas Series?

# %%
#✅ NumPy Array
A NumPy array is:

A homogeneous data structure (all elements must be of the same type).

Only stores values (numbers, strings, etc.).

Does NOT have labels (only numeric indices).
# Out:
#   Cell In[46], line 2
#     A NumPy array is:
#       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
arr = np.array([10, 20, 30])

# %%
###✅ pandas Series
A pandas Series is:

A labeled one-dimensional array.

Can store heterogeneous data (mixed types).

Has both:

values

index labels (customizable)
# Out:
#   Cell In[48], line 2
#     A pandas Series is:
#       ^
# SyntaxError: invalid syntax

# %%
##import pandas as pd
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
###How do you create a histogram using matplotlib?

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(mtcars['mpg'])
plt.xlabel('price')
plt.ylabel('wt')
plt.title('Histogram of Column')
plt.show()

# %%
plt.hist(mtcars['mpg'])
plt.xlabel('10')
plt.ylabel('8')
plt.title('Histogram of Column')
plt.show()

# %%
plt.figure(figsize=(8, 5))   # width=8 inches, height=5 inches
plt.plot([1, 2, 3, 4])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot([1, 2, 3])
plt.show()

# %%
#✅ Basic Example: Multiple Lines

# %%
x = [1, 2, 3, 4]

plt.plot(x, [1, 4, 9, 16], label='Line 1')
plt.plot(x, [2, 3, 2, 3], label='Line 2')

plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Multiple Lines in One Plot")
plt.show()

# %%
##✅ What Seaborn Is Used For

# %%
##1. Statistical Data Visualization

Seaborn is great for visualizing distributions, relationships, and categorical data.

Examples:

Histograms

Box plots

Violin plots

Pair plots

Heatmaps

Regression plots
# Out:
#   Cell In[61], line 3
#     Seaborn is great for visualizing distributions, relationships, and categorical data.
#                      ^
# SyntaxError: invalid syntax

# %%
##Basic Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = mtcars.corr()       # compute correlation matrix
sns.heatmap(corr, annot=True)
plt.show()

# %%
###How do you random sample rows from a DataFrame?

# %%
mtcars.sample(n=4)
# Out:
#                 index  mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  \
# 23         Camaro Z28   26  8.0  350.0  245  3.73  3.84  15.41   0   0     3
# 4   Hornet Sportabout   36  8.0  360.0  175  3.15  3.44  17.02   0   0     3
# 0           Mazda RX4   42  6.0  160.0  110  3.90  2.62  16.46   0   1     4
# 11         Merc 450SE   32  8.0  275.8  180  3.07  4.07  17.40   0   0     3
#
#     carb
# 23     4
# 4      2
# 0      4
# 11     3

# %%
##How do you reset the index of a DataFrame?

# %%
mtcars.reset_index(inplace=True)

# %%
mtcars.head()
# Out:
#                index  mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4   42  6.0  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag   42  6.0  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710   44  4.0  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive   42  6.0  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout   36  8.0  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
##mtcars.reset_index(inplace=True)

# %%
##You can check the number of unique values in a pandas column using either nunique() or unique().

# %%
mtcars['mpg'].nunique()
# Out:
# 16

# %%
mtcars['cyl'].unique()
# Out:
# array([6., 4., 8.])

# %%
###How do you merge multiple CSV files into one DataFrame?

# %%
##you can merge (combine) multiple CSV files into one pandas DataFrame using either a loop or glob to read all files automatically.

# %%
import pandas as pd
import glob

# %%
df = pd.concat((pd.read_csv("C:analytics/data/PIIT data - pstudents1 (1).csv") for f in files), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df = pd.concat((pd.read_csv("C:analytics/data/PIIT data - pstudents1 (1).csv") for f in files), ignore_index=True)
#
# NameError: name 'files' is not defined
