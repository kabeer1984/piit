# %% [markdown]
# ## import table from mysql to jupyter

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q("show tables")
# Out:
#       Tables_in_piit
# 0            authors
# 1              books
# 2        departments
# 3  employee_earnings
# 4          employees
# 5     exceldatafile1
# 6             mtcars
# 7           students
# 8          students2
# 9              team1

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
       return pd.read_sql(text(sql),conn,params=params)

# %%
q("show tables")
# Out:
#       Tables_in_piit
# 0            authors
# 1              books
# 2        departments
# 3  employee_earnings
# 4          employees
# 5     exceldatafile1
# 6             mtcars
# 7           students
# 8          students2
# 9              team1

# %%
q("select * from employee_earnings limit 10")
# Out:
#   the_geom  cartodb_id the_geom_webmercator  objectid  calendar_year  quarter  \
# 0     None           1                 None   2972571           2023        4
# 1     None           2                 None   2972572           2022        4
# 2     None           3                 None   2972573           2022        4
# 3     None           4                 None   2972574           2019        4
# 4     None           5                 None   2972575           2022        3
# 5     None           6                 None   2972576           2022        4
# 6     None           7                 None   2972577           2022        1
# 7     None           8                 None   2972578           2019        4
# 8     None           9                 None   2972579           2025        2
# 9     None          10                 None   2972580           2019        4
#
#     last_name first_name                       title job_code  ...  \
# 0       Guess      Monte      Deputy Sheriff Captain     6K06  ...
# 1    Massi Jr       John             Police Sergeant     6A04  ...
# 2       Guess      Monte      Deputy Sheriff Captain     6K06  ...
# 3       Timms      James            Police Officer 1     6A02  ...
# 4   Mcquilkin    Charles                 Firefighter     6B01  ...
# 5    Feinberg      Louis        Tipstaff 1 (General)     T251  ...
# 6     Kennedy     Sharon  Data Service Support Clerk     1D41  ...
# 7       Betts      Perry            Police Officer 1     6A02  ...
# 8    Rauscher    Stephen                 Firefighter     6B01  ...
# 9  Wallington    Michael       School Crossing Guard     6D44  ...
#
#   overtime_gross_pay_qtd  base_gross_pay_qtd  longevity_gross_pay_qtd  \
# 0                    NaN           -51996.95                   -93.09
# 1                    NaN           -51012.07                 -4067.88
# 2                    NaN           -31078.69                 -3698.42
# 3                    NaN           -28578.51                 -1725.40
# 4               10636.58           -28472.37                  -940.08
# 5                    NaN           -19171.31                      NaN
# 6                -306.82           -13386.98                  -226.50
# 7                    NaN            -8579.10                  -517.00
# 8                    NaN            -6525.36                 -1405.34
# 9                    NaN            -4868.30                      NaN
#
#   post_separation_gross_pay_qtd  miscellaneous_gross_pay_qtd  \
# 0                          None                      1400.00
# 1                          None                     -4036.47
# 2                          None                         0.00
# 3                          None                     -1716.09
# 4                          None                     43048.77
# 5                          None                     30571.62
# 6                          None                     20163.14
# 7                          None                      -514.76
# 8                          None                      3449.37
# 9                          None                         0.00
#
#    employee_category  compulsory_union_code termination_month  \
# 0      Civil Service                      B               NaN
# 1      Civil Service                      P               NaN
# 2      Civil Service                      B               NaN
# 3      Civil Service                      P               6.0
# 4      Civil Service                      F               NaN
# 5             Exempt                      K               NaN
# 6      Civil Service                      M               NaN
# 7      Civil Service                      P               NaN
# 8      Civil Service                      F               NaN
# 9      Civil Service                      G               6.0
#
#    termination_year public_id
# 0               NaN     34277
# 1               NaN     20121
# 2               NaN     34277
# 3            2016.0     36785
# 4               NaN     28977
# 5               NaN      7403
# 6               NaN     33701
# 7               NaN     20445
# 8               NaN     14324
# 9            2020.0     17787
#
# [10 rows x 24 columns]

# %% [markdown]
# #import csv or excel table from data folder  to jupyter

# %%
import pymysql
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
file_path=("C://analytics/data/citydata.csv")
print (file_path)
# Out:
# C://analytics/data/citydata.csv

# %%
df = pd.read_csv(file_path)
df.shape
# Out:
# (808653, 24)

# %%
df.head ()
# Out:
#    the_geom  cartodb_id  the_geom_webmercator  objectid  calendar_year  \
# 0       NaN           1                   NaN   2972571           2023
# 1       NaN           2                   NaN   2972572           2022
# 2       NaN           3                   NaN   2972573           2022
# 3       NaN           4                   NaN   2972574           2019
# 4       NaN           5                   NaN   2972575           2022
#
#    quarter  last_name first_name                   title job_code  ...  \
# 0        4      Guess      Monte  Deputy Sheriff Captain     6K06  ...
# 1        4   Massi Jr       John         Police Sergeant     6A04  ...
# 2        4      Guess      Monte  Deputy Sheriff Captain     6K06  ...
# 3        4      Timms      James        Police Officer 1     6A02  ...
# 4        3  Mcquilkin    Charles             Firefighter     6B01  ...
#
#   overtime_gross_pay_qtd  base_gross_pay_qtd  longevity_gross_pay_qtd  \
# 0                    NaN           -51996.95                   -93.09
# 1                    NaN           -51012.07                 -4067.88
# 2                    NaN           -31078.69                 -3698.42
# 3                    NaN           -28578.51                 -1725.40
# 4               10636.58           -28472.37                  -940.08
#
#   post_separation_gross_pay_qtd  miscellaneous_gross_pay_qtd  \
# 0                           NaN                      1400.00
# 1                           NaN                     -4036.47
# 2                           NaN                         0.00
# 3                           NaN                     -1716.09
# 4                           NaN                     43048.77
#
#    employee_category  compulsory_union_code  termination_month  \
# 0      Civil Service                      B                NaN
# 1      Civil Service                      P                NaN
# 2      Civil Service                      B                NaN
# 3      Civil Service                      P                6.0
# 4      Civil Service                      F                NaN
#
#    termination_year public_id
# 0               NaN     34277
# 1               NaN     20121
# 2               NaN     34277
# 3            2016.0     36785
# 4               NaN     28977
#
# [5 rows x 24 columns]

# %% [markdown]
# ##export from sql to jupyter

# %%
import pymysql
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q("show tables")
# Out:
#       Tables_in_piit
# 0            authors
# 1              books
# 2        departments
# 3  employee_earnings
# 4          employees
# 5     exceldatafile1
# 6             mtcars
# 7           students
# 8          students2
# 9              team1

# %%
q("show tables")
# Out:
#       Tables_in_piit
# 0            authors
# 1              books
# 2        departments
# 3  employee_earnings
# 4          employees
# 5     exceldatafile1
# 6             mtcars
# 7           students
# 8          students2
# 9              team1

# %%
file_path=("C:/analytics/data/citydata.csv")
print(file_path)
# Out:
# C:/analytics/data/citydata.csv

# %%
df1=pd.read_csv(file_path)
df1.head()
# Out:
#    the_geom  cartodb_id  the_geom_webmercator  objectid  calendar_year  \
# 0       NaN           1                   NaN   2972571           2023
# 1       NaN           2                   NaN   2972572           2022
# 2       NaN           3                   NaN   2972573           2022
# 3       NaN           4                   NaN   2972574           2019
# 4       NaN           5                   NaN   2972575           2022
#
#    quarter  last_name first_name                   title job_code  ...  \
# 0        4      Guess      Monte  Deputy Sheriff Captain     6K06  ...
# 1        4   Massi Jr       John         Police Sergeant     6A04  ...
# 2        4      Guess      Monte  Deputy Sheriff Captain     6K06  ...
# 3        4      Timms      James        Police Officer 1     6A02  ...
# 4        3  Mcquilkin    Charles             Firefighter     6B01  ...
#
#   overtime_gross_pay_qtd  base_gross_pay_qtd  longevity_gross_pay_qtd  \
# 0                    NaN           -51996.95                   -93.09
# 1                    NaN           -51012.07                 -4067.88
# 2                    NaN           -31078.69                 -3698.42
# 3                    NaN           -28578.51                 -1725.40
# 4               10636.58           -28472.37                  -940.08
#
#   post_separation_gross_pay_qtd  miscellaneous_gross_pay_qtd  \
# 0                           NaN                      1400.00
# 1                           NaN                     -4036.47
# 2                           NaN                         0.00
# 3                           NaN                     -1716.09
# 4                           NaN                     43048.77
#
#    employee_category  compulsory_union_code  termination_month  \
# 0      Civil Service                      B                NaN
# 1      Civil Service                      P                NaN
# 2      Civil Service                      B                NaN
# 3      Civil Service                      P                6.0
# 4      Civil Service                      F                NaN
#
#    termination_year public_id
# 0               NaN     34277
# 1               NaN     20121
# 2               NaN     34277
# 3            2016.0     36785
# 4               NaN     28977
#
# [5 rows x 24 columns]

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
df1.to_csv('C:/analytics/data/citydata2.csv')
