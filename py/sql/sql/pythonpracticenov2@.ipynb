# %% [markdown]
# #Read csv file

# %%
import pymysql
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
file_path ="C:analytics/data/mtcars.csv"
print (file_path)
# Out:
# C:analytics/data/mtcars.csv

# %%
file_path = 'C:/analytics/data/mtcars.csv'
print(file_path)
# Out:
# C:/analytics/data/mtcars.csv

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
file_path = "C:/analytics/data/Evdata.csv"
print (file_path)
# Out:
# C:/analytics/data/Evdata.csv

# %%
df=pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  WA1E2AFY8R   Thurston       Olympia    WA      98512.0        2024
# 1  WAUUPBFF4J     Yakima        Wapato    WA      98951.0        2018
# 2  1N4AZ0CP0F       King       Seattle    WA      98125.0        2015
# 3  WA1VAAGE5K       King          Kent    WA      98031.0        2019
# 4  7SAXCAE57N  Snohomish       Bothell    WA      98021.0        2022
# 5  KNDJP3AEXG  Snohomish      Lynnwood    WA      98037.0        2016
# 6  1N4AZ1CP7K  Snohomish       Edmonds    WA      98026.0        2019
# 7  KNDCC3LG4L  Snohomish         Brier    WA      98036.0        2020
# 8  KM8JFDD27S     Kitsap     Bremerton    WA      98311.0        2025
# 9  1C4JJXR6XM       Sauk  Spring Green    WI      53588.0        2021
#
#       Make     Model                   Electric Vehicle Type  \
# 0     AUDI      Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 1     AUDI        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
df.to_csv("C:/analytics/data/Evdata5.csv")

# %% [markdown]
# engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")

# %%
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
engine1= create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")

# %%
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
     with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q("show databases")
# Out:
#              Database
# 0  information_schema
# 1  performance_schema
# 2                piit

# %%
q("show tables")
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10           students
# 11          students2
# 12              team1

# %%
df2=pd.read_csv("C:/analytics/data/piitstdata.csv")
df2.head(10)
# Out:
#   rollno  english  maths  python
# 0   P100       79     75      66
# 1   P101       71     56      91
# 2   P102       62     69      78
# 3   P103       63     57      70
# 4   P104       81     52      98
# 5   P105       85     70      94
# 6   P106       94     60      85
# 7   P107       93     84      67
# 8   P108       59     81      61
# 9   P109       70     97      86

# %%
df2.to_sql( name='piitstdata', con=engine1, if_exists='append', index=False )
# Out:
# 15

# %%
q("show tables")
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10         piitstdata
# 11           students
# 12          students2
# 13              team1

# %%
q("show tables")
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10         piitstdata
# 11           students
# 12          students2
# 13              team1

# %%
q("select * from team1")
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1001    Akhansh    Mandal   26  150000
# 1    1002    Muhammd    Kabeer   41  150000
# 2    1003     Suroor     Ahmed   25  120000
# 3    1004   Jugartha  Halchemy   28  100000
# 4    1005    Nayeema    Zannat   25  100000
# 5    1006   Amandeep      Kaur   25  100000
# 6    1007    Sultana   Parveen   25  100000
# 7    1008     Sharan     Shaha   23  100000
# 8    1009     Delwar   Hossain   28  110000

# %%
q("select * from piitstdata")
# Out:
#    rollno  english  maths  python
# 0    P100       79     75      66
# 1    P101       71     56      91
# 2    P102       62     69      78
# 3    P103       63     57      70
# 4    P104       81     52      98
# 5    P105       85     70      94
# 6    P106       94     60      85
# 7    P107       93     84      67
# 8    P108       59     81      61
# 9    P109       70     97      86
# 10   P110       73     91      50
# 11   P111       70     89      64
# 12   P112       77     66      78
# 13   P113       71     70      81
# 14   P123       69     75      50

# %%
q("select * from piitstdata limit ")
# Out:
#   rollno  english  maths  python
# 0   P100       79     75      66
# 1   P101       71     56      91
# 2   P102       62     69      78
# 3   P103       63     57      70
# 4   P104       81     52      98
