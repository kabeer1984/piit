# %%
from sqlalchemy import create_engine
import pandas as pd
import os
import pymysql

# %%
file_path=("C:/analytics/data/obisdata.csv")
print(file_path)
# Out:
# C:/analytics/data/obisdata.csv

# %%
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    OBJECTID        NAME  Obesity   Shape__Area  Shape__Length
# 0         1       Texas     32.4  7.672329e+12   1.540832e+07
# 1         2  California     24.2  5.327809e+12   1.451870e+07
# 2         3    Kentucky     34.6  1.128830e+12   6.346699e+06
# 3         4     Georgia     30.7  1.652980e+12   5.795596e+06
# 4         5   Wisconsin     30.7  1.567816e+12   6.806782e+06

# %%
file_path=("C:/analytics/data/employees.csv")
print(file_path)
# Out:
# C:/analytics/data/employees.csv

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#   employee_id;"first_name";"last_name";"department";"salary"
# 0                        1;"John";"Doe";"HR";55000.0
# 1                      2;"Jane";"Smith";"IT";60000.0
# 2              3;"Alice";"Johnson";"Finance";55000.0
# 3                    4;"Bob";"Williams";"IT";62000.0
# 4                     5;"Emily";"Brown";"HR";48000.0

# %%
file_path=("C:/analytics/data/students3.csv")
print(file_path)
# Out:
# C:/analytics/data/students3.csv

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0  rollno      name  gender         dob  height program
# 0           0       1  Jugurtha    Male  2000-08-16     156     BCA
# 1           1       2  Amandeep  Female  2000-02-21     170     BBA
# 2           2       3    Barkat  Female  2001-07-17     158     BCA
# 3           3       4    Suroor  Female  2001-11-16     188     BBA
# 4           4       5   Sultana    Male  2001-04-02     167     BCA

# %%
file_path=("C:/analytics/data/CUSTOMERAGE.xlsx")
print(file_path)
# Out:
# C:/analytics/data/CUSTOMERAGE.xlsx

# %%
df=pd.read_xlsx(file_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df=pd.read_xlsx(file_path)
#       2 df.head()
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
file_path=("C:/analytics/data/Evdata.csv")
print(file_path)
# Out:
# C:/analytics/data/Evdata.csv

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  WA1E2AFY8R   Thurston  Olympia    WA      98512.0        2024    AUDI
# 1  WAUUPBFF4J     Yakima   Wapato    WA      98951.0        2018    AUDI
# 2  1N4AZ0CP0F       King  Seattle    WA      98125.0        2015  NISSAN
# 3  WA1VAAGE5K       King     Kent    WA      98031.0        2019    AUDI
# 4  7SAXCAE57N  Snohomish  Bothell    WA      98021.0        2022   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 1       A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 2     LEAF          Battery Electric Vehicle (BEV)
# 3   E-TRON          Battery Electric Vehicle (BEV)
# 4  MODEL X          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0              Not eligible due to low battery range            23.0
# 1              Not eligible due to low battery range            16.0
# ...
