# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1 = create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,** params):
    with engine1.connect() as conn:
        return pd.read_sql(text(),conn,params=params)

# %%
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %%
q("SELECT * FROM employees")
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
q("SELECT * FROM employees")
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
q("SELECT * FROM team1")
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1001    Akhansh    Mandal   26  150000
# 1    1002    Muhammd    Kabeer   41  150000
# 2    1003     Suroor     Ahmed   25  120000
# 3    1004   Jugartha  Halchemy   28  100000
# 4    1005    Nayeema    Zannat   25  100000
# 5    1006   Amandeep      Kaur   25  100000
# 6    1007    Sultana   Parveen   25  100000
# 7    1008     Sharan     Shaha   23  100000
# 8    1009     Delwar   Hossain   28  110000

# %%
q("SELECT * FROM team1 where Salary>100000 ")
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1001    Akhansh    Mandal   26  150000
# 1    1002    Muhammd    Kabeer   41  150000
# 2    1003     Suroor     Ahmed   25  120000
# 3    1009     Delwar   Hossain   28  110000

# %%
q('select * from employees')
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
q('select * from team1 where Salary =100000')
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1004   Jugartha  Halchemy   28  100000
# 1    1005    Nayeema    Zannat   25  100000
# 2    1006   Amandeep      Kaur   25  100000
# 3    1007    Sultana   Parveen   25  100000
# 4    1008     Sharan     Shaha   23  100000

# %%
q('SELECT * FROM team1')
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1001    Akhansh    Mandal   26  150000
# 1    1002    Muhammd    Kabeer   41  150000
# 2    1003     Suroor     Ahmed   25  120000
# 3    1004   Jugartha  Halchemy   28  100000
# 4    1005    Nayeema    Zannat   25  100000
# 5    1006   Amandeep      Kaur   25  100000
# 6    1007    Sultana   Parveen   25  100000
# 7    1008     Sharan     Shaha   23  100000
# 8    1009     Delwar   Hossain   28  110000

# %%
q('SELECT * FROM employees')
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
q('select * from employees where employee_id <5')
# Out:
#    employee_id     name  department_id
# 0            1    Alice              1
# 1            2      Bob              2
# 2            3  Charlie              1
# 3            4    David              3

# %%
q('select * from mtcars')
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb make_year  \
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4      None
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4      None
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1      None
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1      None
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2      None
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1      None
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4      None
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2      None
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2      None
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4      None
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4      None
# ...
