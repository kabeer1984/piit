# %% [markdown]
# ##load data to jupyter or python coding

# %%
import pymysql
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
file_path=("C:/analytics/data/obisdata.csv")
print(file_path)

# %%
df=pd.read_csv(file_path)
df.head()

# %% [markdown]
# ##send a worked table back to data folder

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)

# %%
df.to_csv('C:/analytics/data/obisdata1.csv')

# %% [markdown]
# #operate tables from sql  in the  jupyter envirnment

# %% [markdown]
# import pandas as pd
# from sqlalchemy import create_engine,text
# import pymysql
# import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('show tables')

# %%
q('select * from mtcars limit 10')

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)

# %%
file_path=("C:/analytics/data/mtcars.csv")
print(file_path)

# %%
file_path=("C:/analytics/data/mtcars.csv")
print(file_path)

# %%
q('show tables')

# %%
q('select * from mtcars limit 10')

# %%
df.to_sql('obisdata',engine1, if_exists='append',index=False,chunksize=1000,method='multi')

# %%
q('show tables')

# %%
q('select * from obisdata limit 10')

# %%
q("show tables")

# %%
file_path=("C:/analytics/data/crimedata.csv")
print(file_path)

# %%
df=pd.read_csv(file_path)
df.head()

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)

# %% [markdown]
# #table send back to sql

# %%
df.to_sql('obisdata',engine1, if_exists='append',index=False,chunksize=1000,method='multi')

# %%
df.to_sql('crimedata',engine1,if_exists='append',index=False,chunksize=1000,method='multi')

# %%
q('show tables')
