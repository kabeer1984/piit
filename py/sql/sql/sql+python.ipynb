# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql (text(sql),conn,params=params)

# %%
q('show tables')
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6      exceldatafile1
# 7              mtcars
# 8            obisdata
# 9            students
# 10          students2
# 11              team1

# %%
q('select * from crimedata limit 10')
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Part 1-2, Crm Cd, Crm Cd Desc, Mocodes, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Used Cd, Weapon Desc, Status, Status Desc, Crm Cd 1, Crm Cd 2, Crm Cd 3, Crm Cd 4, LOCATION, Cross Street, LAT, LON]
# Index: []
#
# [0 rows x 28 columns]

# %%
q('describe crimedata')
# Out:
#              Field    Type Null Key Default Extra
# 0            DR_NO  bigint  YES        None
# 1        Date Rptd    text  YES        None
# 2         DATE OCC    text  YES        None
# 3         TIME OCC  bigint  YES        None
# 4             AREA  bigint  YES        None
# 5        AREA NAME    text  YES        None
# 6      Rpt Dist No  bigint  YES        None
# 7         Part 1-2  bigint  YES        None
# 8           Crm Cd  bigint  YES        None
# 9      Crm Cd Desc    text  YES        None
# 10         Mocodes    text  YES        None
# 11        Vict Age  bigint  YES        None
# 12        Vict Sex    text  YES        None
# 13    Vict Descent    text  YES        None
# 14       Premis Cd  double  YES        None
# 15     Premis Desc    text  YES        None
# 16  Weapon Used Cd  double  YES        None
# 17     Weapon Desc    text  YES        None
# 18          Status    text  YES        None
# 19     Status Desc    text  YES        None
# ...

# %%
file_path=("c:/analytics/data/Evdata.csv")
print (file_path)
# Out:
# c:/analytics/data/Evdata.csv

# %%
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  WA1E2AFY8R   Thurston  Olympia    WA      98512.0        2024    AUDI
# 1  WAUUPBFF4J     Yakima   Wapato    WA      98951.0        2018    AUDI
# 2  1N4AZ0CP0F       King  Seattle    WA      98125.0        2015  NISSAN
# 3  WA1VAAGE5K       King     Kent    WA      98031.0        2019    AUDI
# 4  7SAXCAE57N  Snohomish  Bothell    WA      98021.0        2022   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 1       A3  Plug-in Hybrid Electric Vehicle (PHEV)
# 2     LEAF          Battery Electric Vehicle (BEV)
# 3   E-TRON          Battery Electric Vehicle (BEV)
# 4  MODEL X          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0              Not eligible due to low battery range            23.0
# 1              Not eligible due to low battery range            16.0
# ...

# %%
df.to_sql('Evdata', engine1, if_exists='append', index=False, chunksize=1000, method='multi')
# Out:
# C:\Users\13616\AppData\Local\Temp\ipykernel_24284\3193548808.py:1: UserWarning: The provided table name 'Evdata' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Evdata', engine1, if_exists='append', index=False, chunksize=1000, method='multi')
# 264628

# %%
q('show tables')
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10           students
# 11          students2
# 12              team1

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123")

# %%
df.to_excel('C:/analytics/data/Evdata1.csv')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# ...
