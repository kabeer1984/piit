# %%
from sqlalchemy import create_engine, text
import pandas as pd 
import os

# %%
engine1 = create_engine ("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1= create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1= create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('select * from employees')
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('select * from employees')
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q("select * from team1")
# Out:
#    ser_id first_name last_name  age  Salary
# 0    1001    Akhansh    Mandal   26  150000
# 1    1002    Muhammd    Kabeer   41  150000
# 2    1003     Suroor     Ahmed   25  120000
# 3    1004   Jugartha  Halchemy   28  100000
# 4    1005    Nayeema    Zannat   25  100000
# 5    1006   Amandeep      Kaur   25  100000
# 6    1007    Sultana   Parveen   25  100000
# 7    1008     Sharan     Shaha   23  100000
# 8    1009     Delwar   Hossain   28  110000

# %% [markdown]
# ##practice from the begaining ,how to fetch data from SQL to PYTHON (jupyter)

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1=create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")

# %%
print (engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('select * from employees')
# Out:
#    employee_id     name  department_id
# 0            1    Alice            1.0
# 1            2      Bob            2.0
# 2            3  Charlie            1.0
# 3            4    David            3.0
# 4            5      Eve            NaN

# %%
q('show tables')
# Out:
#    Tables_in_piit
# 0         authors
# 1           books
# 2     departments
# 3       employees
# 4  exceldatafile1
# 5          mtcars
# 6        students
# 7       students2
# 8           team1

# %% [markdown]
# #again

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1= create_engine("mysql+pymysql://piuser:Pass%40123@localhost/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost/piit)

# %%
def q(sql,**params):
      with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
def q(sql,**params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('show tables')
# Out:
#    Tables_in_piit
# 0         authors
# 1           books
# 2     departments
# 3       employees
# 4  exceldatafile1
# 5          mtcars
# 6        students
# 7       students2
# 8           team1

# %% [markdown]
# #final revision

# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1= create_engine("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")

# %%
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q('select * from students')
# Out:
#    student_id First_name Last_name         Major   Year_Lavel  GPA
# 0         101   Muhammad    Kabeer       Finance  Second Year  4.0
# 1         102    Akhansh    Mandal  Data Science  Second Year  4.0
# 2         103     Suroor     Ahmed            IT  Second Year  4.0

# %%
q('select first_name from students where student_id = 101,102')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
# ...
