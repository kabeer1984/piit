# %% [markdown]
# ### HYPOHESIS T- TEST

# %%
import numpy as np 
from scipy import stats

# %%
##data
sample_data = np.array([95,102, 110, 108, 105, 111, 113, 107, 100, 109, 112, 98, 106, 115, 103])
print(sample_data)
hypothesized_mean=100
# Out:
# [ 95 102 110 108 105 111 113 107 100 109 112  98 106 115 103]

# %%
t_statistic, p_value = stats.ttest_1samp(a=sample_data, popmean=hypothesized_mean)
print(t_statistic, p_value)
# Out:
# 4.202607224264383 0.0008860405739915955

# %% [markdown]
# - Ho : mu = 100 (if pvalue > 0.05) : failed to reject Ho
# - Ha : mu != 100 (if pvalue < 0.05); reject Ho infavour of Ha

# %%
if p_value < .05:
    print("Conclusion: Reject the null hypothesis", p_value)
    print("The sample mean is significantly different from the hypothesized population mean.")
else:
    print("Conclusion: Fail to reject the null hypothesis.")
    print("There is no significant difference between the sample mean and the hypothesized population mean.")
# Out:
# Conclusion: Reject the null hypothesis 0.0008860405739915955
# The sample mean is significantly different from the hypothesized population mean.

# %%
if p
