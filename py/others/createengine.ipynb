# %%
from sqlalchemy import create_engine,text
import pandas as pd
import os

# %%
engine1 = create_engine ("mysql+pymysql://piuser:Pass%40123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://piuser:***@localhost:3306/piit)

# %%
def q(sql,**params):
    with engine1.connect () as conn:
        return pd.read_sql(text(sql),conn,params=params)

# %%
q("show databases")
# Out:
#              Database
# 0  information_schema
# 1  performance_schema
# 2                piit

# %%
q("show tables")
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10         piitstdata
# 11           students
# 12          students2
# 13              team1

# %%
q("select * from departments limit 10")
# Out:
#    department_id department_name studentsqty
# 0              1              HR        None
# 1              2     Engineering        None
# 2              3       Marketing        None
# 3              4         Finance        None

# %%
q("select * from piitstdata limit 10")
# Out:
#   rollno  english  maths  python
# 0   P100       79     75      66
# 1   P101       71     56      91
# 2   P102       62     69      78
# 3   P103       63     57      70
# 4   P104       81     52      98
# 5   P105       85     70      94
# 6   P106       94     60      85
# 7   P107       93     84      67
# 8   P108       59     81      61
# 9   P109       70     97      86

# %%
q("select * from piitstdata")
# Out:
#    rollno  english  maths  python
# 0    P100       79     75      66
# 1    P101       71     56      91
# 2    P102       62     69      78
# 3    P103       63     57      70
# 4    P104       81     52      98
# 5    P105       85     70      94
# 6    P106       94     60      85
# 7    P107       93     84      67
# 8    P108       59     81      61
# 9    P109       70     97      86
# 10   P110       73     91      50
# 11   P111       70     89      64
# 12   P112       77     66      78
# 13   P113       71     70      81
# 14   P123       69     75      50

# %%
q("select rollno from piitstdata where maths> 60")
# Out:
#    rollno
# 0    P100
# 1    P102
# 2    P105
# 3    P107
# 4    P108
# 5    P109
# 6    P110
# 7    P111
# 8    P112
# 9    P113
# 10   P123

# %%
q("select rollno from piitstdata where maths> 60 and python > 90")
# Out:
#   rollno
# 0   P105

# %%
q("select * from students2")
# Out:
#     rollno        name  gender         dob  height program
# 0        1    Jugurtha    Male  2000-08-16     156     BCA
# 1        2    Amandeep  Female  2000-02-21     170     BBA
# 2        3      Barkat  Female  2001-07-17     158     BCA
# 3        4      Suroor  Female  2001-11-16     188     BBA
# 4        5     Sultana    Male  2001-04-02     167     BCA
# 5        6      Sajjad    Male  2000-10-12     153     BCA
# 6        7      Sharan    Male  2000-07-28     174     BBA
# 7        8    Djedjiga  Female  2000-06-27     163     BCA
# 8        9      Bijata  Female  2002-05-14     158     BBA
# 9       10      Mahadi  Female  2000-03-06     175     BCA
# 10      11      Sundas    Male  2000-03-02     151     BCA
# 11      12      Mandal    Male  2000-07-10     169     BBA
# 12      13      Najmul  Female  2001-03-23     177     BCA
# 13      14       Deniz    Male  2001-04-21     156     BBA
# 14      15     Sharmin    Male  2002-10-31     157     BCA
# ...

# %%
q("SELECT name from students2 where program='BBA'")
# Out:
#           name
# 0     Amandeep
# 1       Suroor
# 2       Sharan
# 3       Bijata
# 4       Mandal
# 5        Deniz
# 6        Emran
# 7       Sundas
# 8   Student_20
# 9   Student_24
# 10  Student_25
# 11  Student_26
# 12  Student_27
# 13  Student_28
# 14  Student_29
# 15  Student_30

# %%
q("SELECT name,gender from students2 where program='BBA'")
# Out:
#           name  gender
# 0     Amandeep  Female
# 1       Suroor  Female
# 2       Sharan    Male
# 3       Bijata  Female
# 4       Mandal    Male
# 5        Deniz    Male
# 6        Emran    Male
# 7       Sundas    Male
# 8   Student_20    Male
# 9   Student_24    None
# 10  Student_25  Female
# 11  Student_26    None
# 12  Student_27    Male
# 13  Student_28  Female
# 14  Student_29  Female
# 15  Student_30    Male

# %%
q("SELECT name,gender from students2 where program='BBA' limit 5")
# Out:
#        name  gender
# 0  Amandeep  Female
# 1    Suroor  Female
# 2    Sharan    Male
# 3    Bijata  Female
# 4    Mandal    Male

# %%
q("show tables")
# Out:
#        Tables_in_piit
# 0             authors
# 1               books
# 2           crimedata
# 3         departments
# 4   employee_earnings
# 5           employees
# 6              evdata
# 7      exceldatafile1
# 8              mtcars
# 9            obisdata
# 10         piitstdata
# 11           students
# 12          students2
# 13              team1

# %%
q("SELECT * FROM evdata limit 10")
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  WA1E2AFY8R   Thurston       Olympia    WA      98512.0        2024
# 1  WAUUPBFF4J     Yakima        Wapato    WA      98951.0        2018
# 2  1N4AZ0CP0F       King       Seattle    WA      98125.0        2015
# 3  WA1VAAGE5K       King          Kent    WA      98031.0        2019
# 4  7SAXCAE57N  Snohomish       Bothell    WA      98021.0        2022
# 5  KNDJP3AEXG  Snohomish      Lynnwood    WA      98037.0        2016
# 6  1N4AZ1CP7K  Snohomish       Edmonds    WA      98026.0        2019
# 7  KNDCC3LG4L  Snohomish         Brier    WA      98036.0        2020
# 8  KM8JFDD27S     Kitsap     Bremerton    WA      98311.0        2025
# 9  1C4JJXR6XM       Sauk  Spring Green    WI      53588.0        2021
#
#       Make     Model                   Electric Vehicle Type  \
# 0     AUDI      Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 1     AUDI        A3  Plug-in Hybrid Electric Vehicle (PHEV)
# ...
