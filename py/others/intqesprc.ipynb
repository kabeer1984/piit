# %% [markdown]
# diffeence among list,tuple & dictionary:
# list is ordered collection of data which is changable or mutable.
# list data use [] in coding.
# tuple is ordered collection of data but they are not changabo.
# tupple uses () incoding
# dictioary is unordered and mutable collection of data inside {}
# Here is a clear comparison of List, Tuple, and Dictionary in Python (interview-friendly):
#
# Feature	List	Tuple	Dictionary
# Order	Ordered	Ordered	Unordered (conceptually)
# Mutability	Mutable (can change)	Immutable (cannot change)	Mutable
# Syntax	[]	()	{key: value}
# Access	By index	By index	By key
# Speed	Slower than tuple	Faster than list	Fast lookups
# Use case	Dynamic data	Fixed data	Key-value data

# %%
import pandas as pd
from pydataset import data
import numpy as np
