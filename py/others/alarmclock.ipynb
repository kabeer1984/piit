# %%
from datetime import datetime

# %%
alarm_time = input("Enter the time of the alarm to be set:HH:MM:SS/n")
alarm_hour=alarm_time[0:2]
# Out:
# Enter the time of the alarm to be set:HH:MM:SS/n 11:10:10

# %%
alarm_minute=alarm_time[3:5]

# %%
alarm_second=alarm_time[6:8]

# %%
alarm_period = alarm_time[9:11].upper()

# %%
print("Setting up alarm")

# %%
while true:

# %%
now = datetime.now()

# %%
current_hour = now.strtime("%I")

# %%
current_minute = now.strftime("%M")

# %%
current_seconds = now.starftime("%S")

# %%
current_period = now.strftime("%p")

# %%
if(alarm_period==current_period):

# %%
if(alarm_hour==current_hour):

# %%
if(alarm_minute==current_minute):

# %%
if(alarm_seconds==current_seconds):

# %%
print("wake up!")

# %%
playsound(''audio.mp3)

# %%
break
