# %% [markdown]
# # List

# %%
x = [1,3,2,6,29.9,'Suroor','Mandal','piit']

# %%
x
# Out:
# [1, 3, 2, 6, 29.9, 'Suroor', 'Mandal', 'piit']

# %%
 x1= [5,3,4,6.7,'Nayeema','Ashik']

# %%
x1
# Out:
# [5, 3, 4, 6.7, 'Nayeema', 'Ashik']

# %%
p=x+x1

# %%
p
# Out:
# [1,
#  3,
#  2,
#  6,
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  5,
#  3,
#  4,
#  6.7,
#  'Nayeema',
#  'Ashik']

# %%
type(x)
# Out:
# list

# %%
type(x1),type(p)
# Out:
# (list, list)

# %% [markdown]
# # lenth of list

# %%
len(x),len(x1),len(p)
# Out:
# (8, 6, 14)

# %% [markdown]
# # filter by position

# %% [markdown]
# ## first position start from 0,1,2 so on

# %%
x[0],x1[2],p[5]
# Out:
# (1, 4, 'Suroor')

# %%
p[6]
# Out:
# 'Mandal'

# %% [markdown]
# # change value by position

# %%
x[3]= 'Nyeema'

# %%
x
# Out:
# [1, 3, 2, 'Nyeema', 29.9, 'Suroor', 'Mandal', 'piit']

# %%
x
# Out:
# [1, 3, 2, 'Nyeema', 29.9, 'Suroor', 'Mandal', 'piit']

# %%
x1
# Out:
# [5, 3, 4, 6.7, 'Nayeema', 'Ashik']

# %%
p
# Out:
# [1,
#  3,
#  2,
#  6,
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  5,
#  3,
#  4,
#  6.7,
#  'Nayeema',
#  'Ashik']

# %%
x.append('Kabeer')

# %%
x
# Out:
# [1, 3, 2, 'Nyeema', 29.9, 'Suroor', 'Mandal', 'piit', 'Kabeer', 'Kabeer']

# %%
x1
# Out:
# [5, 3, 4, 6.7, 'Nayeema', 'Ashik', 'Kabeer']

# %%
p
# Out:
# [1,
#  3,
#  2,
#  6,
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  5,
#  3,
#  4,
#  6.7,
#  'Nayeema',
#  'Ashik',
#  'Kabeer**']

# %%
x.insert(3,'data')

# %%
x
# Out:
# [1,
#  3,
#  2,
#  'data',
#  'Nyeema',
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  'Kabeer',
#  'Kabeer']

# %%
x1.insert(2,'sayeed'),p.insert(5,'james')
# Out:
# (None, None)

# %%
x1
# Out:
# [5, 3, 'sayeed', 4, 6.7, 'Nayeema', 'Ashik', 'Kabeer']

# %%
p
# Out:
# [1,
#  3,
#  2,
#  6,
#  29.9,
#  'james',
#  'Suroor',
#  'Mandal',
#  'piit',
#  5,
#  3,
#  4,
#  6.7,
#  'Nayeema',
#  'Ashik',
#  'Kabeer**']

# %%
x.reverse()

# %%
x
# Out:
# ['Kabeer',
#  'Kabeer',
#  'piit',
#  'Mandal',
#  'Suroor',
#  29.9,
#  'Nyeema',
#  'data',
#  2,
#  3,
#  1]

# %%
x1.reverse(),x.reverse()
# Out:
# (None, None)

# %%
x1
# Out:
# ['Kabeer', 'Ashik', 'Nayeema', 6.7, 4, 'sayeed', 3, 5]

# %%
x
# Out:
# [1,
#  3,
#  2,
#  'data',
#  'Nyeema',
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  'Kabeer',
#  'Kabeer']

# %%
p.reverse()

# %%
p
# Out:
# ['Kabeer**',
#  'Ashik',
#  'Nayeema',
#  6.7,
#  4,
#  3,
#  5,
#  'piit',
#  'Mandal',
#  'Suroor',
#  'james',
#  29.9,
#  6,
#  2,
#  3,
#  1]

# %%
x.count('Kabeer')
# Out:
# 2

# %%
p.count('Kabeer')
# Out:
# 0

# %%
p
# Out:
# ['Kabeer**',
#  'Ashik',
#  'Nayeema',
#  6.7,
#  4,
#  3,
#  5,
#  'piit',
#  'Mandal',
#  'Suroor',
#  'james',
#  29.9,
#  6,
#  2,
#  3,
#  1]

# %%
p=x+x1

# %%
p
# Out:
# [1,
#  3,
#  2,
#  'data',
#  'Nyeema',
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  'Kabeer',
#  'Kabeer',
#  'Kabeer',
#  'Ashik',
#  'Nayeema',
#  6.7,
#  4,
#  'sayeed',
#  3,
#  5]

# %%
p.count('Kabeer')
# Out:
# 3

# %%
p
# Out:
# [1,
#  3,
#  2,
#  'data',
#  'Nyeema',
#  29.9,
#  'Suroor',
#  'Mandal',
#  'piit',
#  'Kabeer',
#  'Kabeer',
#  'Kabeer',
#  'Ashik',
#  'Nayeema',
#  6.7,
#  4,
#  'sayeed',
#  3,
#  5]

# %%
p.remove(3)

# %%
p.remove('piit')

# %%
p
# Out:
# [1,
#  2,
#  'data',
#  'Nyeema',
#  29.9,
#  'Suroor',
#  'Mandal',
#  'Kabeer',
#  'Kabeer',
#  'Kabeer',
#  'Ashik',
#  'Nayeema',
#  6.7,
#  4,
#  'sayeed',
#  3,
#  5]

# %%
x1
# Out:
# ['Kabeer', 'Ashik', 'Nayeema', 6.7, 4, 'sayeed', 3, 5]

# %%
x1.remove(3)

# %%
x1
# Out:
# ['Kabeer', 'Ashik', 'Nayeema', 6.7, 4, 'sayeed', 5]

# %%
x1.pop(3)
# Out:
# 6.7

# %%
x1
# Out:
# ['Kabeer', 'Ashik', 'Nayeema', 4, 'sayeed', 5]

# %%
insert.
